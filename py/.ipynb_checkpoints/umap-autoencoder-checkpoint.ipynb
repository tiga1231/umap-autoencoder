# %%
# !pip install umap-learn
# !pip install tqdm
# !pip install tensorflowjs
# Out:
# Collecting umap-learn
#   Downloading https://files.pythonhosted.org/packages/ad/92/36bac74962b424870026cb0b42cec3d5b6f4afa37d81818475d8762f9255/umap-learn-0.3.10.tar.gz (40kB)
#      |████████████████████████████████| 40kB 67kB/s  eta 0:00:01
# Requirement already satisfied: numpy>=1.13 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from umap-learn) (1.16.4)
# Requirement already satisfied: scikit-learn>=0.16 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from umap-learn) (0.21.3)
# Requirement already satisfied: scipy>=0.19 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from umap-learn) (1.3.0)
# Collecting numba>=0.37
#   Downloading https://files.pythonhosted.org/packages/0e/6e/e3bd3b844ee2dd815c313807a6030706845ffa6387e95d20e2eb79370036/numba-0.46.0-cp37-cp37m-macosx_10_9_x86_64.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 220kB/s eta 0:00:01
# Requirement already satisfied: joblib>=0.11 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from scikit-learn>=0.16->umap-learn) (0.13.2)
# Collecting llvmlite>=0.30.0dev0
#   Downloading https://files.pythonhosted.org/packages/ca/ba/1b1e5c4c707c082b1125c30f93887b827ee3db6a2e86184532fe529d31bd/llvmlite-0.30.0-cp37-cp37m-macosx_10_9_x86_64.whl (15.9MB)
#      |████████████████████████████████| 15.9MB 2.0MB/s eta 0:00:01    |██▎                             | 1.1MB 168kB/s eta 0:01:28     |██████▋                         | 3.3MB 377kB/s eta 0:00:34
# Building wheels for collected packages: umap-learn
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.3.10-cp37-none-any.whl size=38881 sha256=eadabdb1c51275bd601ecd7f258c39e6e1af806882cdbe4f00802d3b0480d58f
#   Stored in directory: /Users/jack/Library/Caches/pip/wheels/d0/f8/d5/8e3af3ee957feb9b403a060ebe72f7561887fef9dea658326e
# Successfully built umap-learn
# Installing collected packages: llvmlite, numba, umap-learn
# Successfully installed llvmlite-0.30.0 numba-0.46.0 umap-learn-0.3.10
# Requirement already satisfied: tqdm in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (4.32.2)
# Collecting tensorflowjs
#   Downloading https://files.pythonhosted.org/packages/a7/73/f7ee6edced75b7dfe43916203f1b2e85dd14cba087a090e6372cbd82e462/tensorflowjs-1.4.0-py3-none-any.whl (56kB)
#      |████████████████████████████████| 61kB 99kB/s eta 0:00:01
# Collecting six==1.11.0
#   Downloading https://files.pythonhosted.org/packages/67/4b/141a581104b1f6397bfa78ac9d43d8ad29a7ca43ea90a2d863fe3056e86a/six-1.11.0-py2.py3-none-any.whl
# Requirement already satisfied: gast==0.2.2 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorflowjs) (0.2.2)
# Collecting h5py==2.8.0
#   Downloading https://files.pythonhosted.org/packages/2a/13/d3fb885ff877578e0fddd8c71e1ed9e22207cec8469c0ef1e483ab5ca0d3/h5py-2.8.0-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (6.0MB)
#      |████████████████████████████████| 6.1MB 406kB/s eta 0:00:01
# Requirement already satisfied: numpy==1.16.4 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorflowjs) (1.16.4)
# Collecting tensorflow-hub==0.5.0
#   Downloading https://files.pythonhosted.org/packages/b5/be/f18c352d84382d9c795a0f37eaf16d42ace7d161fbb0ad20bdcd5e550015/tensorflow_hub-0.5.0-py2.py3-none-any.whl (78kB)
#      |████████████████████████████████| 81kB 4.1MB/s eta 0:00:01
# Collecting tensorflow==1.15.0
#   Downloading https://files.pythonhosted.org/packages/dc/65/a94519cd8b4fd61a7b002cb752bfc0c0e5faa25d1f43ec4f0a4705020126/tensorflow-1.15.0-cp37-cp37m-macosx_10_11_x86_64.whl (124.0MB)
#      |████████████████████████████████| 124.0MB 264kB/s eta 0:00:01    |██████▍                         | 24.6MB 3.0MB/s eta 0:00:33     |█████████████████▋              | 68.3MB 2.8MB/s eta 0:00:20     |██████████████████              | 70.1MB 2.8MB/s eta 0:00:19     |███████████████████             | 73.5MB 1.3MB/s eta 0:00:38     |██████████████████████████████  | 116.1MB 400kB/s eta 0:00:20     |███████████████████████████████ | 120.1MB 1.2MB/s eta 0:00:04
# Collecting PyInquirer==1.0.3
#   Downloading https://files.pythonhosted.org/packages/fb/4c/434b7c454010a284b49d6f1d446fe8dc5960415613d8c0225b9e2efb6724/PyInquirer-1.0.3.tar.gz
# Requirement already satisfied: protobuf>=3.4.0 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorflow-hub==0.5.0->tensorflowjs) (3.9.1)
# Collecting opt-einsum>=2.3.2
#   Downloading https://files.pythonhosted.org/packages/b8/83/755bd5324777875e9dff19c2e59daec837d0378c09196634524a3d7269ac/opt_einsum-3.1.0.tar.gz (69kB)
#      |████████████████████████████████| 71kB 4.9MB/s eta 0:00:011
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 1.0MB/s eta 0:00:01
# Requirement already satisfied: absl-py>=0.7.0 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorflow==1.15.0->tensorflowjs) (0.8.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorflow==1.15.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorflow==1.15.0->tensorflowjs) (0.8.0)
# Requirement already satisfied: wheel>=0.26 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorflow==1.15.0->tensorflowjs) (0.33.6)
# Requirement already satisfied: google-pasta>=0.1.6 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorflow==1.15.0->tensorflowjs) (0.1.7)
# Requirement already satisfied: grpcio>=1.8.6 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorflow==1.15.0->tensorflowjs) (1.23.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorflow==1.15.0->tensorflowjs) (1.0.8)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 7.2MB/s eta 0:00:01
# Requirement already satisfied: termcolor>=1.1.0 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorflow==1.15.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorflow==1.15.0->tensorflowjs) (1.11.2)
# Collecting prompt_toolkit==1.0.14
#   Downloading https://files.pythonhosted.org/packages/ee/3d/b25d35a9f0d381dd1c02d8e04b37c353caaaff4bc32150328eeebe4931f5/prompt_toolkit-1.0.14-py3-none-any.whl (248kB)
#      |████████████████████████████████| 256kB 5.0MB/s eta 0:00:01
# Requirement already satisfied: Pygments>=2.2.0 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from PyInquirer==1.0.3->tensorflowjs) (2.4.2)
# Collecting regex>=2016.11.21
#   Downloading https://files.pythonhosted.org/packages/19/69/d5b3bd8ba79b0ef1a18420c802dc7e25b17301c0ac9ed475be627031a852/regex-2019.12.19.tar.gz (679kB)
#      |████████████████████████████████| 686kB 165kB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from protobuf>=3.4.0->tensorflow-hub==0.5.0->tensorflowjs) (41.6.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0->tensorflowjs) (0.15.5)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: wcwidth in /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages (from prompt_toolkit==1.0.14->PyInquirer==1.0.3->tensorflowjs) (0.1.7)
# Building wheels for collected packages: PyInquirer, opt-einsum, regex
#   Building wheel for PyInquirer (setup.py) ... done
#   Created wheel for PyInquirer: filename=PyInquirer-1.0.3-cp37-none-any.whl size=32851 sha256=fbfa3e78c2a39bcfacc4690f21563c11cd4f2c264835c3531ab72a0f8b43d33c
#   Stored in directory: /Users/jack/Library/Caches/pip/wheels/52/6c/b1/3e4b0e8daf42a92883c7641c0ea8ffb62e0490ebed2faa55ad
#   Building wheel for opt-einsum (setup.py) ... done
#   Created wheel for opt-einsum: filename=opt_einsum-3.1.0-cp37-none-any.whl size=61682 sha256=4cdf6021b0d1494cff1d63018ab1a97c5b65468f1d9679b01f09f70ac879403c
#   Stored in directory: /Users/jack/Library/Caches/pip/wheels/2c/b1/94/43d03e130b929aae7ba3f8d15cbd7bc0d1cb5bb38a5c721833
#   Building wheel for regex (setup.py) ... done
#   Created wheel for regex: filename=regex-2019.12.19-cp37-cp37m-macosx_10_14_x86_64.whl size=291532 sha256=1b3365812c3a4de0c734f125528ba15d8a48774cd810fac844fd34e9ea30c0ff
#   Stored in directory: /Users/jack/Library/Caches/pip/wheels/d4/cc/17/75a3645f3314ba8f251ea9128da8d7f93a6bc87f94205e0aa4
# Successfully built PyInquirer opt-einsum regex
# ERROR: torchvision 0.4.0 has requirement torch==1.2.0, but you'll have torch 1.3.1 which is incompatible.
# ERROR: jupyter-console 6.0.0 has requirement prompt-toolkit<2.1.0,>=2.0.0, but you'll have prompt-toolkit 1.0.14 which is incompatible.
# ERROR: ipython 7.6.1 has requirement prompt-toolkit<2.1.0,>=2.0.0, but you'll have prompt-toolkit 1.0.14 which is incompatible.
# Installing collected packages: six, h5py, tensorflow-hub, opt-einsum, tensorboard, tensorflow-estimator, tensorflow, prompt-toolkit, regex, PyInquirer, tensorflowjs
#   Found existing installation: six 1.12.0
#     Uninstalling six-1.12.0:
#       Successfully uninstalled six-1.12.0
#   Found existing installation: h5py 2.9.0
#     Uninstalling h5py-2.9.0:
#       Successfully uninstalled h5py-2.9.0
#   Found existing installation: tensorboard 1.14.0
#     Uninstalling tensorboard-1.14.0:
#       Successfully uninstalled tensorboard-1.14.0
#   Found existing installation: tensorflow-estimator 1.14.0
#     Uninstalling tensorflow-estimator-1.14.0:
#       Successfully uninstalled tensorflow-estimator-1.14.0
#   Found existing installation: tensorflow 1.14.0
#     Uninstalling tensorflow-1.14.0:
#       Successfully uninstalled tensorflow-1.14.0
#   Found existing installation: prompt-toolkit 2.0.9
#     Uninstalling prompt-toolkit-2.0.9:
#       Successfully uninstalled prompt-toolkit-2.0.9
# Successfully installed PyInquirer-1.0.3 h5py-2.8.0 opt-einsum-3.1.0 prompt-toolkit-1.0.14 regex-2019.12.19 six-1.11.0 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1 tensorflow-hub-0.5.0 tensorflowjs-1.4.0

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from IPython import display
from tqdm import tqdm_notebook as tqdm
plt.style.use('ggplot')
plt.style.use('seaborn-colorblind')

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
from torchvision import datasets, transforms
from torchvision.utils import make_grid
from torchvision import models



from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from umap import UMAP
import re
import math
from time import time
import os, shutil
from glob import glob
from natsort import natsorted
import json

# %%
dataset_train = datasets.FashionMNIST('./dataset/', train=True, download=True)
dataset_test = datasets.FashionMNIST('./dataset/', train=False, download=True)

# %%
# %%time
n = 10000
imgs = dataset_train.data[:n].float().numpy()
imgs /= 255.0
labels = dataset_train.targets[:n].numpy().astype(dtype=np.uint8)

umap = UMAP(metric='l1', min_dist=0.4)
embeddings = umap.fit_transform(imgs.reshape([-1,28*28]))

print(
    imgs.shape, embeddings.shape, labels.shape, imgs.dtype, embeddings.dtype, labels.dtype
)

## save computed embeddings and dataset
# !mkdir ./tmp
embeddings.tofile('tmp/embeddings.bin')
labels.tofile('tmp/labels.bin')
imgs.tofile('tmp/imgs.bin')
# Out:
# /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages/numba/typed_passes.py:271: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../.virtualenvs/env3/lib/python3.7/site-packages/umap/rp_tree.py", line 135:
# @numba.njit(fastmath=True, nogil=True, parallel=True)
# def euclidean_random_projection_split(data, indices, rng_state):
# ^
#
#   state.func_ir.loc))
# /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages/umap/nndescent.py:92: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../.virtualenvs/env3/lib/python3.7/site-packages/umap/utils.py", line 409:
# @numba.njit(parallel=True)
# def build_candidates(current_graph, n_vertices, n_neighbors, max_candidates, rng_state):
# ^
#
#   current_graph, n_vertices, n_neighbors, max_candidates, rng_state
# /Users/jack/.virtualenvs/env3/lib/python3.7/site-packages/numba/typed_passes.py:271: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../.virtualenvs/env3/lib/python3.7/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   state.func_ir.loc))
#
# 4423680it [00:35, 183598.48it/s]
# (10000, 28, 28) (10000, 2) (10000,) float32 float32 uint8
# CPU times: user 30.4 s, sys: 462 ms, total: 30.9 s
# Wall time: 31.1 s

# %% [markdown]
# ## load computed embeddings and dataset

# %%
# embeddings = np.fromfile('tmp/embeddings.bin', dtype=np.float32).reshape([-1,2])
# imgs = np.fromfile('tmp/imgs.bin', dtype=np.float32).reshape([-1,28,28])
# labels = np.fromfile('tmp/labels.bin', dtype=np.uint8)

# %% [markdown]
# ## show the embedding

# %%
plt.figure(figsize=[7,5])
plt.scatter(embeddings[:,0], embeddings[:,1], s=2, c=labels, cmap='tab10')
plt.colorbar()
plt.axis('square')
plt.title('embeddings')
plt.show()

# %% [markdown]
# ## Create an embedding dataset

# %%
class EmbeddingDataset(Dataset):
    def __init__(self, imgs, embeddings, labels):
        self.imgs = imgs
        self.embeddings = embeddings
        self.labels = labels
    def __len__(self):
        return self.imgs.shape[0]
    
    def __getitem__(self, i):
        return self.imgs[i], self.embeddings[i], self.labels[i]
    
nTrain, nTest = 9000,1000
train_dataset = EmbeddingDataset(imgs[:nTrain], embeddings[:nTrain], labels[:nTrain])
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataset = EmbeddingDataset(imgs[-nTest:], embeddings[-nTest:], labels[-nTest:])
test_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# ## model

# %%
class Lambda(nn.Module):
    def __init__(self, func):
        super().__init__()
        self.func = func

    def forward(self, x):
        return self.func(x)

def preprocess(x):
    return x.view(-1, 1, 28, 28)

def flatten(ndim):
    def f(x):
        return x.view(-1, ndim)
    return f

def postprocess(x):
    return x.view(-1, 28, 28)

class Autoencoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            Lambda(flatten(28*28)),
#             Lambda(preprocess),
#             nn.Conv2d(1,20,3),
#             nn.LeakyReLU(),
#             nn.MaxPool2d(2),
            
            nn.Linear(784,250),
            nn.LeakyReLU(),
            nn.Linear(250,100),
            nn.LeakyReLU(),
            nn.Linear(100,10),
            nn.LeakyReLU(),
            nn.Linear(10,2),
        )
        self.decoder = nn.Sequential(
            nn.Linear(2,100),
            nn.ReLU(),
            nn.Linear(100,100),
            nn.ReLU(),
            nn.Linear(100,784),
            nn.Sigmoid(),
            Lambda(postprocess),
        )
        
    def forward(self,x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %% [markdown]
# ## Util functions for vis

# %%
def imshowGrid(imgs):
    im = make_grid(imgs.cpu().detach().unsqueeze(1), padding=2, pad_value=1).permute(1,2,0)
    plt.imshow(im)
    plt.axis('off')

# %% [markdown]
# ## Training

# %%
use_cuda = torch.cuda.is_available()

model = Autoencoder()
if use_cuda:
    model = model.cuda()
mse = nn.MSELoss()
l1 = nn.L1Loss()
kl = nn.KLDivLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
sigmoid = nn.Sigmoid()

## show progress bar here
nepoch = 30
epochBar = tqdm(range(nepoch))
# Out:
# HBox(children=(IntProgress(value=0, max=30), HTML(value='')))

# %%
gs = GridSpec(2,3,width_ratios=[1.5,1.5,1])
lossHistory = []
for epoch in epochBar:
    for imgs, embeddings, labels in train_loader:
        if use_cuda:
            imgs = imgs.cuda()
            embeddings = embeddings.cuda()
        
        code = model.encoder(imgs)
        recon1 = model.decoder(code) #autoencoder
        recon2 = model.decoder(embeddings) #decoder from ground truth
        

        loss = 1*mse(code, embeddings) + 1*l1(code, embeddings)
        loss += 100*mse(recon1, imgs) + 50*l1(recon1, imgs)
#         loss += 4*mse(recon2, imgs) + 2*l1(recon2, imgs)
        
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        epochBar.set_postfix({'loss': loss.item()})
        lossHistory.append(np.log(loss.item()))
        
    if epoch==0 or epoch % 10 == 9:
        with torch.no_grad():
            display.clear_output(wait=True)
            plt.figure(figsize=[20,6])
            
            plt.subplot(gs[:,0])
            plt.plot(lossHistory)
            plt.title('loss')
            
            plt.subplot(gs[:,1])
            for imgs, embeddings, labels in test_loader:
                if use_cuda:
                    code = model.encoder(imgs.cuda()) 
                else:
                    code = model.encoder(imgs)
                    
                recon = model.decoder(code)
                code = code.cpu().numpy()
                plt.scatter(embeddings[:,0], embeddings[:,1], s=1, c='#333333', zorder=1)
                plt.scatter(code[:,0], code[:,1], s=1, c=labels, cmap='tab10', zorder=2)
                
            plt.colorbar()
            plt.axis('equal')
            plt.title('learned embedding (epoch {}/{})'.format(epoch, nepoch))
#             plt.xlim([-8,6])
#             plt.ylim([-4,6])
            
            plt.subplot(gs[0,2])
            imshowGrid(imgs)
            plt.title('original')
            plt.subplot(gs[1,2])
            imshowGrid(recon)
            plt.title('learned')
            plt.show()

# %% [markdown]
# ## Reload embeddings, get parameters for frontend

# %%
embeddings = np.fromfile('tmp/embeddings.bin', dtype=np.float32).reshape([-1,2])
imgs = np.fromfile('tmp/imgs.bin', dtype=np.float32).reshape([-1,28,28])
labels = np.fromfile('tmp/labels.bin', dtype=np.uint8)

[xmin, ymin] = embeddings.min(axis=0)
[xmax, ymax] = embeddings.max(axis=0)
vmin = torch.tensor([xmin, ymin])
vmax = torch.tensor([xmax, ymax])

print(xmin, xmax, ymin, ymax)
# Out:
# -9.676905 11.995275 -9.280952 6.5920854

# %% [markdown]
# ## Dump data to js files

# %%
data_dir = './reconstruct-fashion/'
# !rm -r $data_dir
# !mkdir $data_dir
# Out:
# rm: ./reconstruct-fashion/: No such file or directory

# %%
with open(data_dir+'constants.js', 'w') as f:
    f.write('let constants = {};\n')
    
    f.write('constants.xrange = \n')
    json.dump([float(xmin), float(xmax)], f)
    f.write(';\n')
    
    f.write('constants.yrange = \n')
    json.dump([float(ymin), float(ymax)], f)
    f.write(';\n')

with open(data_dir+'data.js', 'w') as f:
    f.write('let data = {}; \ndata.embeddings = \n')
    json.dump(embeddings.tolist(), f)
    f.write('\n\n')
    f.write('data.labels = \n')
    json.dump(labels.tolist(), f)

# %% [markdown]
# ## Convert to a tfjs model

# %%
from tensorflow import keras
import tensorflowjs as tfjs

## define a kera model that is equicalent to the pytorch decoder
model_keras = keras.models.Sequential([
    keras.layers.Dense(100, activation='relu', input_shape=(2,)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(784, activation='sigmoid'),
])

## copy the weights
print([w.shape for w in model_keras.get_weights()])
weights = [[model.decoder[i].weight, model.decoder[i].bias]  for i in [0,2,4]]
weights = sum(weights, [])
weights = [w.data.cpu().numpy().T for w in weights]
model_keras.set_weights(weights)

# model_keras.save('model_keras.h5')
tfjs.converters.save_keras_model(model_keras, data_dir)
# Out:
# [(2, 100), (100,), (100, 100), (100,), (100, 784), (784,)]

# %% [markdown]
# ## Compress into a zip (optional)

# %%
zip_filename = data_dir[:-1] + '.zip'
# !rm $zip_filename
# !zip -r $zip_filename $data_dir
# Out:
# rm: ./reconstruct-fashion.zip: No such file or directory
#   adding: reconstruct-fashion/ (stored 0%)
#   adding: reconstruct-fashion/constants.js (deflated 24%)
#   adding: reconstruct-fashion/model.json (deflated 78%)
#   adding: reconstruct-fashion/group1-shard1of1.bin (deflated 7%)
#   adding: reconstruct-fashion/data.js (deflated 58%)
